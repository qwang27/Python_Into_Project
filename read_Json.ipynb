# %%
from Python_project import *

# %%
df = getDF("Movies_and_TV_5.json.gz")

# %%
df.shape
# Out:
# (3410019, 12)

# %%
small_df = df.sample(30000)

# %%
tmp = pd.read_csv('sample_dataset.csv')

# %%
tmp
# Out:
#        overall  verified   reviewTime      reviewerID        asin  \
# 0          1.0     False   02 7, 2012  A36TZ0I34B46XO  B004LWZW7Y
# 1          5.0      True  06 25, 2015  A1YB90PDA4XMX8  6303066720
# 2          5.0     False  09 11, 2014   AVXLG5QWMH2TI  B00006NT1R
# 3          5.0      True  02 19, 2016  A1AZHOD7KIMTY7  B00L905DXE
# 4          5.0      True  06 30, 2017    A6SSF4E2TJK9  B00005JMZK
# ...        ...       ...          ...             ...         ...
# 29995      4.0      True  12 25, 2015  A1Q3X7VBERC3U5  6302020816
# 29996      4.0      True   08 9, 2016   ASZ9P7339G2IN  B01AJ7ELT4
# 29997      5.0      True  06 19, 2015  A2VLO00A5VMAMS  B00SJC9WV4
# 29998      4.0      True  04 11, 2011   AX148M3X6EUGN  B002SVP9GO
# 29999      3.0     False  01 12, 2013  A1Q3GEO516I4VK  B00005JNJR
#
#                               style      reviewerName  \
# 0           {'Format:': ' Blu-ray'}         Jayteedee
# 1               {'Format:': ' DVD'}       L. Andersen
# ...
